# %%
import json
from helper import DataFetcher, Session, Protocol

api_key = "OSOegLs.PR2lwJ1dwCeje9vTj7FPOt3hvpYKtwKkhw"
tf_token = "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"
start_date = "2015-01-01"
end_date = "2026-01-01"
entity = "BT"
resource_type = "plenarprotokoll"
data_fetcher = DataFetcher(api_key=api_key, start_date=start_date, end_date=end_date, 
                           entity=entity, resource_type=resource_type)

data_fetcher = DataFetcher(api_key=api_key)

# Load the speech data
with open('speech_data.json', 'r', encoding='utf-8') as f:
    speeches = json.load(f)

# Find the speech with the highest 'Anger' emotion
most_angry = max(speeches, key=lambda s: s.get('emotions', {}).get('Anger', 0))

print(f"Anger Score: {most_angry['emotions']['Anger']:.4f}")
print(f"Speech ID: {most_angry['speech_id']}")
print(f"Speaker: {most_angry['speaker_first_name']} {most_angry['speaker_last_name']}")
print(f"Party: {most_angry['party']}")
print(f"Date: {most_angry['date']}")

protocol_data = data_fetcher.fetch_protocol_by_id(most_angry['session_id'])
protocol = Protocol(protocol_data['documents'][0])
speakers, speeches_ = protocol.parse_xml()
target_speech = next((s for s in speeches_ if s.id == most_angry['speech_id']), None)
print(target_speech.text)

most_fearful = max(speeches, key=lambda s: s.get('emotions', {}).get('Fear', 0))

print(f"Fear Score: {most_fearful['emotions']['Fear']:.4f}")
print(f"Speech ID: {most_fearful['speech_id']}")
print(f"Speaker: {most_fearful['speaker_first_name']} {most_fearful['speaker_last_name']}")
print(f"Party: {most_fearful['party']}")
print(f"Date: {most_fearful['date']}")

most_joyful = max(speeches, key=lambda s: s.get('emotions', {}).get('Joy', 0))

protocol_data = data_fetcher.fetch_protocol_by_id(most_fearful['session_id'])
protocol = Protocol(protocol_data['documents'][0])
speakers, speeches_ = protocol.parse_xml()
target_speech = next((s for s in speeches_ if s.id == most_fearful['speech_id']), None)
print(target_speech.text)

print(f"Joy Score: {most_joyful['emotions']['Joy']:.4f}")
print(f"Speech ID: {most_joyful['speech_id']}")
print(f"Speaker: {most_joyful['speaker_first_name']} {most_joyful['speaker_last_name']}")
print(f"Party: {most_joyful['party']}")
print(f"Date: {most_joyful['date']}")

protocol_data = data_fetcher.fetch_protocol_by_id(most_joyful['session_id'])
protocol = Protocol(protocol_data['documents'][0])
speakers, speeches_ = protocol.parse_xml()
target_speech = next((s for s in speeches_ if s.id == most_joyful['speech_id']), None)
print(target_speech.text)

most_hopeful = max(speeches, key=lambda s: s.get('emotions', {}).get('Hope', 0))
print(f"Hope Score: {most_hopeful['emotions']['Hope']:.4f}")
print(f"Speech ID: {most_hopeful['speech_id']}")
print(f"Speaker: {most_hopeful['speaker_first_name']} {most_hopeful['speaker_last_name']}")
print(f"Party: {most_hopeful['party']}")
print(f"Date: {most_hopeful['date']}")

protocol_data = data_fetcher.fetch_protocol_by_id(most_hopeful['session_id'])
protocol = Protocol(protocol_data['documents'][0])
speakers, speeches_ = protocol.parse_xml()
target_speech = next((s for s in speeches_ if s.id == most_hopeful['speech_id']), None)
print(target_speech.text)
